# %%
from google.colab import files

# %%
arquivos = files.upload()
# Out:
#      <input type="file" id="files-81da3b20-036e-497b-8a29-229dd687b2e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81da3b20-036e-497b-8a29-229dd687b2e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2 #biblioreca opencv
from google.colab.patches import cv2_imshow #imshow para mostrar img

# %% [markdown]
# RGB e BGR

# %%
#transformar img em matriz
img = cv2.imread('buninho.jpg')
cv2_imshow(img)
img
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>
# array([[[124, 119,  64],
#         [110, 105,  50],
#         [113, 110,  55],
#         ...,
#         [176, 186, 193],
#         [173, 183, 190],
#         [176, 186, 193]],
#
#        [[ 99,  94,  39],
#         [103,  98,  43],
#         [118, 115,  60],
#         ...,
#         [177, 187, 194],
#         [176, 186, 193],
#         [177, 187, 194]],
#
#        [[ 87,  81,  28],
#         [ 99,  93,  40],
#         [109, 103,  50],
#         ...,
#         [178, 188, 195],
#         [181, 191, 198],
#         [180, 190, 197]],
#
#        ...,
#
#        [[ 32,  36,  41],
#         [ 30,  34,  39],
#         [ 28,  34,  39],
#         ...,
#         [ 70,  72,  72],
#         [ 70,  72,  72],
#         [ 69,  71,  71]],
#
#        [[ 31,  35,  40],
#         [ 30,  34,  39],
#         [ 28,  34,  39],
#         ...,
#         [ 70,  72,  72],
#         [ 70,  72,  72],
#         [ 70,  72,  72]],
#
#        [[ 29,  33,  38],
# ...

# %% [markdown]
# visu da estrutura em matriz

# %%
img.shape
print(img)
# Out:
# [[[124 119  64]
#   [110 105  50]
#   [113 110  55]
#   ...
#   [176 186 193]
#   [173 183 190]
#   [176 186 193]]
#
#  [[ 99  94  39]
#   [103  98  43]
#   [118 115  60]
#   ...
#   [177 187 194]
#   [176 186 193]
#   [177 187 194]]
#
#  [[ 87  81  28]
#   [ 99  93  40]
#   [109 103  50]
#   ...
#   [178 188 195]
#   [181 191 198]
#   [180 190 197]]
#
#  ...
#
#  [[ 32  36  41]
#   [ 30  34  39]
#   [ 28  34  39]
#   ...
#   [ 70  72  72]
#   [ 70  72  72]
#   [ 69  71  71]]
#
#  [[ 31  35  40]
#   [ 30  34  39]
#   [ 28  34  39]
#   ...
#   [ 70  72  72]
#   [ 70  72  72]
#   [ 70  72  72]]
#
#  [[ 29  33  38]
#   [ 29  33  38]
#   [ 27  33  38]
#   ...
#   [ 70  72  72]
#   [ 70  72  72]
#   [ 70  72  72]]]

# %% [markdown]
# preto 0 - 255 branco

# %% [markdown]
# ###Alteração manual dos valores dos pixxels

# %%
cv2_imshow(img/2) #itensidade dos pixel pela metade
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
cv2_imshow(img*10)#overflow
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
cv2_imshow(255-img)#inverso negativo
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
B,G,R = cv2.split(img)

# %% [markdown]
# #Visu individual de cada canal de cor

# %%
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=335x597>
# <PIL.Image.Image image mode=L size=335x597>
# <PIL.Image.Image image mode=L size=335x597>
